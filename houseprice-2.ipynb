# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv("house_price_dataset 2.csv")
df
# Out:
#        property_area_sqft  bedrooms  bathrooms  floors  year_built  \
# 0                    3674         4          3       2        1983
# 1                    1360         2          2       1        2006
# 2                    1794         4          2       1        1988
# 3                    1630         2          4       3        1979
# 4                    1595         3          2       1        1972
# ...                   ...       ...        ...     ...         ...
# 99995                1260         5          3       3        1988
# 99996                1622         3          4       3        2016
# 99997                3257         1          2       2        2000
# 99998                3374         3          2       2        2017
# 99999                 707         4          3       3        2006
#
#        renovation_status  lot_size_sqft  distance_city_center_km  \
# 0                      1         5631.0                    11.89
# 1                      0         3272.0                     5.02
# 2                      1         3472.0                    19.92
# 3                      0         1699.0                    25.54
# 4                      0         3662.0                    13.41
# ...                  ...            ...                      ...
# 99995                  1            NaN                    29.17
# 99996                  1         5186.0                    11.65
# 99997                  0         1616.0                     9.99
# 99998                  0         3410.0                     3.75
# 99999                  0         3851.0                    13.23
#
#        neighborhood_quality  crime_rate_index  ...  construction_quality  \
# 0                       1.3              69.5  ...                   8.8
# 1                       6.3              61.7  ...                   7.3
# 2                       1.1              59.5  ...                   6.3
# 3                       7.0              68.1  ...                   8.5
# 4                       9.5               1.9  ...                   7.6
# ...                     ...               ...  ...                   ...
# 99995                   6.9              92.2  ...                   7.6
# 99996                   9.6              55.0  ...                   8.4
# 99997                   5.8              44.6  ...                   8.1
# 99998                   4.0              85.2  ...                   9.3
# 99999                   2.4              17.7  ...                   8.7
#
#        energy_efficiency  water_supply_score  electricity_supply_score  \
# 0                    6.5                 3.4                       7.3
# 1                    3.3                 5.6                       2.7
# 2                    3.5                 5.0                       6.9
# 3                    5.1                 8.9                       1.3
# 4                    1.6                 4.4                       7.0
# ...                  ...                 ...                       ...
# 99995                4.7                 6.1                       9.9
# 99996                9.7                 3.1                       4.0
# 99997                5.8                 5.1                       3.0
# 99998                4.1                 4.5                       5.9
# 99999                6.6                 7.0                       4.2
#
#        internet_score green_space_index  flood_risk_index  \
# 0                 5.6               9.9               9.5
# 1                 6.6               5.2               9.3
# 2                 NaN               6.5               1.0
# 3                 4.7               6.1               4.8
# 4                 5.1               8.4               3.8
# ...               ...               ...               ...
# 99995             4.3               9.3               4.7
# 99996             7.0               1.6               5.6
# 99997             8.7               4.7               7.6
# 99998             7.7               1.3               7.9
# 99999             6.3               1.1               7.4
#
#        noise_pollution_level  property_age   house_price
# 0                        2.4            42  1.806542e+07
# 1                        4.2            19  9.839487e+06
# 2                        6.4            37  7.775089e+06
# 3                        6.8            46  7.654648e+06
# 4                        2.4            53  1.038060e+07
# ...                      ...           ...           ...
# 99995                    7.2            37  7.798233e+06
# 99996                    4.1             9  1.202463e+07
# 99997                    8.6            25  1.808469e+07
# 99998                    7.7             8  1.900305e+07
# 99999                    4.1            19  3.407399e+06
#
# [100000 rows x 26 columns]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   property_area_sqft        100000 non-null  int64
#  1   bedrooms                  100000 non-null  int64
#  2   bathrooms                 100000 non-null  int64
#  3   floors                    100000 non-null  int64
#  4   year_built                100000 non-null  int64
#  5   renovation_status         100000 non-null  int64
#  6   lot_size_sqft             100000 non-null  float64
#  7   distance_city_center_km   100000 non-null  float64
#  8   neighborhood_quality      100000 non-null  float64
#  9   crime_rate_index          100000 non-null  float64
#  10  school_rating             100000 non-null  float64
#  11  hospital_distance_km      100000 non-null  float64
#  12  shopping_distance_km      100000 non-null  float64
#  13  public_transport_score    100000 non-null  float64
#  14  parking_available         100000 non-null  int64
#  15  property_type             100000 non-null  str
#  16  construction_quality      100000 non-null  float64
#  17  energy_efficiency         100000 non-null  float64
#  18  water_supply_score        100000 non-null  float64
#  19  electricity_supply_score  100000 non-null  float64
#  20  internet_score            100000 non-null  float64
#  21  green_space_index         100000 non-null  float64
#  22  flood_risk_index          100000 non-null  float64
#  23  noise_pollution_level     100000 non-null  float64
#  24  property_age              100000 non-null  int64
#  25  house_price               100000 non-null  float64
# dtypes: float64(17), int64(8), str(1)
# memory usage: 19.8 MB
#        property_area_sqft       bedrooms      bathrooms         floors  \
# count        100000.00000  100000.000000  100000.000000  100000.000000
# mean           2249.54639       2.999470       2.497390       2.001530
# std            1010.69636       1.415327       1.116963       0.818177
# min             500.00000       1.000000       1.000000       1.000000
# 25%            1374.00000       2.000000       2.000000       1.000000
# 50%            2250.00000       3.000000       2.000000       2.000000
# 75%            3124.00000       4.000000       3.000000       3.000000
# max            3999.00000       5.000000       4.000000       3.000000
#
#           year_built  renovation_status  lot_size_sqft  \
# count  100000.000000      100000.000000  100000.000000
# mean     1996.507830           0.500980    3408.854526
# std        15.576799           0.500002    1462.794750
# min      1970.000000           0.000000     800.000000
# 25%      1983.000000           0.000000    2182.000000
# 50%      1997.000000           1.000000    3408.854526
# 75%      2010.000000           1.000000    4650.000000
# max      2023.000000           1.000000    5999.000000
#
#        distance_city_center_km  neighborhood_quality  crime_rate_index  ...  \
# count            100000.000000         100000.000000     100000.000000  ...
# mean                 15.274379              5.504676         50.457837  ...
# std                   8.280225              2.602513         28.551116  ...
# min                   0.500000              1.000000          1.000000  ...
# 25%                   8.340000              3.200000         25.700000  ...
# 50%                  15.274379              5.500000         50.500000  ...
# 75%                  22.240000              7.800000         75.100000  ...
# max                  30.000000             10.000000        100.000000  ...
#
#        construction_quality  energy_efficiency  water_supply_score  \
# count          100000.00000      100000.000000       100000.000000
# mean                5.49596           5.486962            5.500049
# std                 2.52571           2.530622            2.598421
# min                 1.00000           1.000000            1.000000
# 25%                 3.40000           3.400000            3.300000
# 50%                 5.49596           5.486962            5.500000
# 75%                 7.60000           7.600000            7.700000
# max                10.00000          10.000000           10.000000
#
#        electricity_supply_score  internet_score  green_space_index  \
# count             100000.000000   100000.000000      100000.000000
# mean                   5.489868        5.501043           5.495056
# std                    2.598326        2.531272           2.600320
# min                    1.000000        1.000000           1.000000
# 25%                    3.300000        3.400000           3.200000
# 50%                    5.500000        5.501043           5.500000
# 75%                    7.700000        7.600000           7.800000
# max                   10.000000       10.000000          10.000000
#
#        flood_risk_index  noise_pollution_level   property_age   house_price
# count     100000.000000          100000.000000  100000.000000  1.000000e+05
# mean           5.487975               5.504176      28.492170  1.239517e+07
# std            2.597161               2.595652      15.576799  5.218312e+06
# min            1.000000               1.000000       2.000000  1.677959e+05
# 25%            3.200000               3.300000      15.000000  8.024390e+06
# 50%            5.500000               5.500000      28.000000  1.238141e+07
# 75%            7.700000               7.700000      42.000000  1.676066e+07
# max           10.000000              10.000000      55.000000  2.484709e+07
#
# [8 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# property_area_sqft             0
# bedrooms                       0
# bathrooms                      0
# floors                         0
# year_built                     0
# renovation_status              0
# lot_size_sqft               5000
# distance_city_center_km     5000
# neighborhood_quality           0
# crime_rate_index               0
# school_rating               5000
# hospital_distance_km        5000
# shopping_distance_km           0
# public_transport_score         0
# parking_available              0
# property_type                  0
# construction_quality        5000
# energy_efficiency           5000
# water_supply_score             0
# electricity_supply_score       0
# internet_score              5000
# green_space_index              0
# flood_risk_index               0
# noise_pollution_level          0
# property_age                   0
# house_price                    0
# dtype: int64

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

df.fillna(df.mode().iloc[0], inplace=True)
# Out:
#        property_area_sqft  bedrooms  bathrooms  floors  year_built  \
# 0                  3674.0       4.0        3.0     2.0      1983.0
# 1                  1360.0       2.0        2.0     1.0      2006.0
# 2                  1794.0       4.0        2.0     1.0      1988.0
# 3                  1630.0       2.0        4.0     3.0      1979.0
# 4                  1595.0       3.0        2.0     1.0      1972.0
# ...                   ...       ...        ...     ...         ...
# 99995              1260.0       5.0        3.0     3.0      1988.0
# 99996              1622.0       3.0        4.0     3.0      2016.0
# 99997              3257.0       1.0        2.0     2.0      2000.0
# 99998              3374.0       3.0        2.0     2.0      2017.0
# 99999               707.0       4.0        3.0     3.0      2006.0
#
#        renovation_status  lot_size_sqft  distance_city_center_km  \
# 0                    1.0    5631.000000                    11.89
# 1                    0.0    3272.000000                     5.02
# 2                    1.0    3472.000000                    19.92
# 3                    0.0    1699.000000                    25.54
# 4                    0.0    3662.000000                    13.41
# ...                  ...            ...                      ...
# 99995                1.0    3408.854526                    29.17
# 99996                1.0    5186.000000                    11.65
# 99997                0.0    1616.000000                     9.99
# 99998                0.0    3410.000000                     3.75
# 99999                0.0    3851.000000                    13.23
#
#        neighborhood_quality  crime_rate_index  ...  construction_quality  \
# 0                       1.3              69.5  ...                   8.8
# 1                       6.3              61.7  ...                   7.3
# 2                       1.1              59.5  ...                   6.3
# 3                       7.0              68.1  ...                   8.5
# 4                       9.5               1.9  ...                   7.6
# ...                     ...               ...  ...                   ...
# 99995                   6.9              92.2  ...                   7.6
# 99996                   9.6              55.0  ...                   8.4
# 99997                   5.8              44.6  ...                   8.1
# 99998                   4.0              85.2  ...                   9.3
# 99999                   2.4              17.7  ...                   8.7
#
#        energy_efficiency  water_supply_score  electricity_supply_score  \
# 0                    6.5                 3.4                       7.3
# 1                    3.3                 5.6                       2.7
# 2                    3.5                 5.0                       6.9
# 3                    5.1                 8.9                       1.3
# 4                    1.6                 4.4                       7.0
# ...                  ...                 ...                       ...
# 99995                4.7                 6.1                       9.9
# 99996                9.7                 3.1                       4.0
# 99997                5.8                 5.1                       3.0
# 99998                4.1                 4.5                       5.9
# 99999                6.6                 7.0                       4.2
#
#        internet_score  green_space_index  flood_risk_index  \
# 0            5.600000                9.9               9.5
# 1            6.600000                5.2               9.3
# 2            5.501043                6.5               1.0
# 3            4.700000                6.1               4.8
# 4            5.100000                8.4               3.8
# ...               ...                ...               ...
# 99995        4.300000                9.3               4.7
# 99996        7.000000                1.6               5.6
# 99997        8.700000                4.7               7.6
# 99998        7.700000                1.3               7.9
# 99999        6.300000                1.1               7.4
#
#        noise_pollution_level  property_age   house_price
# 0                        2.4          42.0  1.806542e+07
# 1                        4.2          19.0  9.839487e+06
# 2                        6.4          37.0  7.775089e+06
# 3                        6.8          46.0  7.654648e+06
# 4                        2.4          53.0  1.038060e+07
# ...                      ...           ...           ...
# 99995                    7.2          37.0  7.798233e+06
# 99996                    4.1           9.0  1.202463e+07
# 99997                    8.6          25.0  1.808469e+07
# 99998                    7.7           8.0  1.900305e+07
# 99999                    4.1          19.0  3.407399e+06
#
# [100000 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# property_area_sqft          0
# bedrooms                    0
# bathrooms                   0
# floors                      0
# year_built                  0
# renovation_status           0
# lot_size_sqft               0
# distance_city_center_km     0
# neighborhood_quality        0
# crime_rate_index            0
# school_rating               0
# hospital_distance_km        0
# shopping_distance_km        0
# public_transport_score      0
# parking_available           0
# property_type               0
# construction_quality        0
# energy_efficiency           0
# water_supply_score          0
# electricity_supply_score    0
# internet_score              0
# green_space_index           0
# flood_risk_index            0
# noise_pollution_level       0
# property_age                0
# house_price                 0
# dtype: int64

# %%
X = df.drop("house_price", axis=1)
y = df["house_price"]

# %%
X
y
# Out:
# 0        1.806542e+07
# 1        9.839487e+06
# 2        7.775089e+06
# 3        7.654648e+06
# 4        1.038060e+07
#              ...
# 99995    7.798233e+06
# 99996    1.202463e+07
# 99997    1.808469e+07
# 99998    1.900305e+07
# 99999    3.407399e+06
# Name: house_price, Length: 100000, dtype: float64

# %%
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# property_area_sqft          0
# bedrooms                    0
# bathrooms                   0
# floors                      0
# year_built                  0
# renovation_status           0
# lot_size_sqft               0
# distance_city_center_km     0
# neighborhood_quality        0
# crime_rate_index            0
# school_rating               0
# hospital_distance_km        0
# shopping_distance_km        0
# public_transport_score      0
# parking_available           0
# property_type               0
# construction_quality        0
# energy_efficiency           0
# water_supply_score          0
# electricity_supply_score    0
# internet_score              0
# green_space_index           0
# flood_risk_index            0
# noise_pollution_level       0
# property_age                0
# house_price                 0
# dtype: int64

# %%
df = pd.get_dummies(df, drop_first=True)
df
# Out:
#        property_area_sqft  bedrooms  bathrooms  floors  year_built  \
# 0                  3674.0       4.0        3.0     2.0      1983.0
# 1                  1360.0       2.0        2.0     1.0      2006.0
# 2                  1794.0       4.0        2.0     1.0      1988.0
# 3                  1630.0       2.0        4.0     3.0      1979.0
# 4                  1595.0       3.0        2.0     1.0      1972.0
# ...                   ...       ...        ...     ...         ...
# 99995              1260.0       5.0        3.0     3.0      1988.0
# 99996              1622.0       3.0        4.0     3.0      2016.0
# 99997              3257.0       1.0        2.0     2.0      2000.0
# 99998              3374.0       3.0        2.0     2.0      2017.0
# 99999               707.0       4.0        3.0     3.0      2006.0
#
#        renovation_status  lot_size_sqft  distance_city_center_km  \
# 0                    1.0    5631.000000                    11.89
# 1                    0.0    3272.000000                     5.02
# 2                    1.0    3472.000000                    19.92
# 3                    0.0    1699.000000                    25.54
# 4                    0.0    3662.000000                    13.41
# ...                  ...            ...                      ...
# 99995                1.0    3408.854526                    29.17
# 99996                1.0    5186.000000                    11.65
# 99997                0.0    1616.000000                     9.99
# 99998                0.0    3410.000000                     3.75
# 99999                0.0    3851.000000                    13.23
#
#        neighborhood_quality  crime_rate_index  ...  construction_quality  \
# 0                       1.3              69.5  ...                   8.8
# 1                       6.3              61.7  ...                   7.3
# 2                       1.1              59.5  ...                   6.3
# 3                       7.0              68.1  ...                   8.5
# 4                       9.5               1.9  ...                   7.6
# ...                     ...               ...  ...                   ...
# 99995                   6.9              92.2  ...                   7.6
# 99996                   9.6              55.0  ...                   8.4
# 99997                   5.8              44.6  ...                   8.1
# 99998                   4.0              85.2  ...                   9.3
# 99999                   2.4              17.7  ...                   8.7
#
#        energy_efficiency  water_supply_score  electricity_supply_score  \
# 0                    6.5                 3.4                       7.3
# 1                    3.3                 5.6                       2.7
# 2                    3.5                 5.0                       6.9
# 3                    5.1                 8.9                       1.3
# 4                    1.6                 4.4                       7.0
# ...                  ...                 ...                       ...
# 99995                4.7                 6.1                       9.9
# 99996                9.7                 3.1                       4.0
# 99997                5.8                 5.1                       3.0
# 99998                4.1                 4.5                       5.9
# 99999                6.6                 7.0                       4.2
#
#        internet_score  green_space_index  flood_risk_index  \
# 0            5.600000                9.9               9.5
# 1            6.600000                5.2               9.3
# 2            5.501043                6.5               1.0
# 3            4.700000                6.1               4.8
# 4            5.100000                8.4               3.8
# ...               ...                ...               ...
# 99995        4.300000                9.3               4.7
# 99996        7.000000                1.6               5.6
# 99997        8.700000                4.7               7.6
# 99998        7.700000                1.3               7.9
# 99999        6.300000                1.1               7.4
#
#        noise_pollution_level  property_age   house_price
# 0                        2.4          42.0  1.806542e+07
# 1                        4.2          19.0  9.839487e+06
# 2                        6.4          37.0  7.775089e+06
# 3                        6.8          46.0  7.654648e+06
# 4                        2.4          53.0  1.038060e+07
# ...                      ...           ...           ...
# 99995                    7.2          37.0  7.798233e+06
# 99996                    4.1           9.0  1.202463e+07
# 99997                    8.6          25.0  1.808469e+07
# 99998                    7.7           8.0  1.900305e+07
# 99999                    4.1          19.0  3.407399e+06
#
# [100000 rows x 26 columns]

# %%
num_cols = df.select_dtypes(include=np.number).columns
cat_cols = df.select_dtypes(include='object').columns

num_imputer = SimpleImputer(strategy='mean')
df[num_cols] = num_imputer.fit_transform(df[num_cols])

cat_imputer = SimpleImputer(strategy='most_frequent')
df[cat_cols] = cat_imputer.fit_transform(df[cat_cols])
# Out:
# /var/folders/cs/nzbztsl55v52vgp0mq6bs_7r0000gn/T/ipykernel_33305/2908736133.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include='object').columns

# %%
le = LabelEncoder()

for col in cat_cols:
    df[col] = le.fit_transform(df[col])

# %%
le
# Out:
# LabelEncoder()

# %%
scaler = StandardScaler()
X = df.drop('house_price', axis=1)
y = df['house_price']

X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[ 1.40938544e+00,  7.06928642e-01,  4.49981468e-01, ...,
#          1.54478087e+00, -1.19591955e+00,  8.67180580e-01],
#        [-8.80136580e-01, -7.06179695e-01, -4.45308056e-01, ...,
#          1.46777333e+00, -5.02448820e-01, -6.09381780e-01],
#        [-4.50727524e-01,  7.06928642e-01, -4.45308056e-01, ...,
#         -1.72803956e+00,  3.45126511e-01,  5.46188763e-01],
#        ...,
#        [ 9.96796553e-01, -1.41273386e+00, -4.45308056e-01, ...,
#          8.13209241e-01,  1.19270184e+00, -2.24191599e-01],
#        [ 1.11255890e+00,  3.74473709e-04, -4.45308056e-01, ...,
#          9.28720550e-01,  8.45966479e-01, -1.31556378e+00],
#        [-1.52622901e+00,  7.06928642e-01,  4.49981468e-01, ...,
#          7.36201702e-01, -5.40974972e-01, -6.09381780e-01]],
#       shape=(100000, 25))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred_lr = lr.predict(X_test)

# %%
y_pred_lr
# Out:
# array([15384597.13745121, 19115303.73671787, 18365595.12419897, ...,
#        16898650.29974816, 10127445.50963532,  3762980.42756152],
#       shape=(20000,))

# %%
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

y_pred_rf
# Out:
# array([15139263.20593061, 18915395.99545905, 18034195.92742337, ...,
#        17375808.69588477, 10263515.89406425,  3962269.59197207],
#       shape=(20000,))

# %%
def evaluate(y_test, y_pred):
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    print("MAE:", mae)
    print("MSE:", mse)
    print("RMSE:", rmse)
    print("R2 Score:", r2)

# %%
print("Linear Regression:")
evaluate(y_test, y_pred_lr)

print("\nRandom Forest:")
evaluate(y_test, y_pred_rf)
# Out:
# Linear Regression:
# MAE: 491129.4772125908
# MSE: 386224386246.8564
# RMSE: 621469.537666052
# R2 Score: 0.9858088544676381
#
# Random Forest:
# MAE: 539339.8194294828
# MSE: 463306169781.336
# RMSE: 680665.975189987
# R2 Score: 0.9829766179569879

# %%
plt.scatter(y_test, y_pred_rf)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted")
plt.show()

# %%
residuals = y_test - y_pred_rf

sns.histplot(residuals, kde=True)
plt.title("Residual Distribution")
plt.show()

# %%
importances = rf.feature_importances_
feature_names = X.columns

feat_imp = pd.Series(importances, index=feature_names)
feat_imp.nlargest(10).plot(kind='barh')
plt.title("Top Features Affecting Price")
plt.show()
